# %% [markdown]
# # **Import Libraries**

# %%
#Set path to MAIN FOLDER OF EXPERIMENT
#cd /path/to/EXPERIMENT_FOLDER/

# %%
#Import Models APIs
from tensorflow.keras.layers import Input, Average, Dropout, Dense, GlobalAveragePooling2D
from keras.layers import Resizing
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.applications import inception_resnet_v2
from tensorflow.keras.applications import efficientnet 
from tensorflow.keras.applications import densenet
from tensorflow.keras.applications import inception_v3
from tensorflow.keras.applications import nasnet
from tensorflow.keras.applications import mobilenet_v2
from tensorflow.keras.applications import resnet_v2
from tensorflow.keras.applications import xception
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
import itertools
import tensorflow as tf
import pandas as pd
import numpy as np
import math
import os

print("LIBRARIES LOADED")
# Out:
# LIBRARIES LOADED

# %%
#Tweakable parameters
MODEL_KIND = "teacher_model"
MODEL_NAME = "EnsembleModel"

IMAGE_SIZE = (224, 224)
BATCH_SIZE = 4

ENSEMBLE_FILES = ['EfficientNetB7',
                  'DenseNet201',
                  'DenseNet121',
                  'InceptionResNetV2', 
                  'InceptionV3', 
                  'NASNetLarge', 
                  'EfficientNetB0'] 
#                   'Xception', 
#                   'MobileNetV2', 
#                   'ResNet152V2', 
#                   'ResNet50V2', 
#                   'NASNetMobile']

#Data paths
MAIN_DATA_DIR = "ds/"
TRAIN_DATA_DIR = MAIN_DATA_DIR + "train/"
TEST_DATA_DIR = MAIN_DATA_DIR + "test/"
VALIDATION_DATA_DIR = MAIN_DATA_DIR + "val/"

#Model path
TEACHER_MODEL_PATH = 'models/teacher_model/'

print("ALL REQUERED PATHS SET")
# Out:
# ALL REQUERED PATHS SET

# %%
#Save Model Function
def save_m(model, directory, model_name):
    if not os.path.exists(directory):
        os.makedirs(directory)
    model.save(directory + "/" + model_name + ".h5")

#Load model Function
def load_m(directory, model_name):
    if not os.path.exists(directory):
        print("Model File Does Not Exist!!")
        return 
    model = load_model(directory + "/" + model_name + ".h5")
    return model

#Get Ensemble Function with given input shape
def get_ensemble(all_models, to_ensemble, input_shape=IMAGE_SIZE):
	emodels = []
	ensemble_input = Input(shape=(input_shape[0], input_shape[1], 3), name='ensemble_input')
	for model_name in to_ensemble:
		emodel = all_models[model_name]
		emodel = add_preprocess_layer(emodel, processing_layers[model_name], ensemble_input)
		emodel = rename_all_layers(emodel, model_name)
		emodels.append(emodel)

	outputs = [m.output for m in emodels]
	y = Average()(outputs) 
	model = Model(inputs=ensemble_input , outputs=y, name=MODEL_KIND + '-' + MODEL_NAME)
	return model

#Add resizing and preprocessing layer to model
def add_preprocess_layer(emodel, pre_layer, ensemble_input):
	input_shape = emodel.inputs[0].shape
	x = Resizing(input_shape[1], input_shape[2])(ensemble_input)
	x = pre_layer()(x)
	outputs = emodel(x)
	model = Model(inputs = ensemble_input, outputs = outputs)
	return model

#Rename all layers except input layer of model
def rename_all_layers(model, file):
	for i in range(1, len(model.layers)):
		model.layers[i]._name = model.layers[i]._name + '_' + file

	return model

print("ALL CUSTOM FUNCTIONS DEFIEND")
# Out:
# ALL CUSTOM FUNCTIONS DEFIEND

# %% [markdown]
# **Preprocessing Layers**

# %%
class EN_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(EN_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = efficientnet.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(EN_PreprocessLayer, self).get_config()
        return config

class Dense_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(Dense_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = densenet.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(Dense_PreprocessLayer, self).get_config()
        return config

class IRNV2_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(IRNV2_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = inception_resnet_v2.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(IRNV2_PreprocessLayer, self).get_config()
        return config

class INV3_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(INV3_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = inception_v3.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(INV3_PreprocessLayer, self).get_config()
        return config
    
class NN_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(NN_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = nasnet.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(NN_PreprocessLayer, self).get_config()
        return config

class XCT_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(XCT_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = xception.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(XCT_PreprocessLayer, self).get_config()
        return config

class MNV2_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(MNV2_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = mobilenet_v2.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(MNV2_PreprocessLayer, self).get_config()
        return config

class RNV2_PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self, name="preprocess", **kwargs):
        super(RNV2_PreprocessLayer, self).__init__(name=name, **kwargs)
        self.preprocess = resnet_v2.preprocess_input

    def call(self, input):
        return self.preprocess(input)

    def get_config(self):
        config = super(RNV2_PreprocessLayer, self).get_config()
        return config

processing_layers = {'EfficientNetB7':EN_PreprocessLayer, 
                     'DenseNet121':Dense_PreprocessLayer,
                     'DenseNet201':Dense_PreprocessLayer,
                     'InceptionResNetV2':IRNV2_PreprocessLayer,
                     'InceptionV3':INV3_PreprocessLayer, 
                     'NASNetLarge':NN_PreprocessLayer, 
                     'EfficientNetB0':EN_PreprocessLayer, 
                     'Xception':XCT_PreprocessLayer, 
                     'MobileNetV2':MNV2_PreprocessLayer, 
                     'ResNet152V2':RNV2_PreprocessLayer, 
                     'ResNet50V2':RNV2_PreprocessLayer, 
                     'NASNetMobile':NN_PreprocessLayer }

print("ALL REQUERED PREPROCESSING LAYERS DEFINED")
# Out:
# ALL REQUERED PREPROCESSING LAYERS DEFINED

# %%
teacher_models = {}

for file in ENSEMBLE_FILES:
	teacher_models[file] = {}

#Actual models
teacher_models['DenseNet201'] = load_m(TEACHER_MODEL_PATH + 'DenseNet201', 'DenseNet201')
teacher_models['DenseNet121'] = load_m(TEACHER_MODEL_PATH + 'DenseNet121', 'DenseNet121')
teacher_models['InceptionResNetV2'] = load_m(TEACHER_MODEL_PATH + 'InceptionResNetV2', 'InceptionResNetV2')
teacher_models['InceptionV3'] = load_m(TEACHER_MODEL_PATH + 'InceptionV3', 'InceptionV3')
teacher_models['EfficientNetB7'] = load_m(TEACHER_MODEL_PATH + 'EfficientNetB7', 'EfficientNetB7')
teacher_models['NASNetLarge'] = load_m(TEACHER_MODEL_PATH + 'NASNetLarge', 'NASNetLarge')
teacher_models['EfficientNetB0'] = load_m(TEACHER_MODEL_PATH + 'EfficientNetB0', 'EfficientNetB0')
teacher_models['Xception'] = load_m(TEACHER_MODEL_PATH + 'Xception', 'Xception')
teacher_models['MobileNetV2'] = load_m(TEACHER_MODEL_PATH + 'MobileNetV2', 'MobileNetV2')
teacher_models['ResNet152V2'] = load_m(TEACHER_MODEL_PATH + 'ResNet152V2', 'ResNet152V2')
teacher_models['ResNet50V2'] = load_m(TEACHER_MODEL_PATH + 'ResNet50V2', 'ResNet50V2')
teacher_models['NASNetMobile'] = load_m(TEACHER_MODEL_PATH + 'NASNetMobile', 'NASNetMobile')

print("[INFO] Load models")
# Out:
# [INFO] Load models

# %%
#LOAD TEST & VAL DATA
val_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

if not os.path.exists(VALIDATION_DATA_DIR):
    print("VALIDATION DATA DOES NOT EXITS!")
else:
    print("LOAD VALIDATION SAMPLES...")
    validation_generator = val_datagen.flow_from_directory(
        VALIDATION_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        seed=42,
        shuffle=False)

    #CHECK  THE NUMBER OF SAMPLES
    nb_validation_samples = len(validation_generator.filenames)
    if nb_validation_samples == 0:
        print("NO DATA VALIDATION FOUND IN VALIDATION FOLDER!")

print()
if not os.path.exists(TEST_DATA_DIR):
    print("TEST DATA DOES NOT EXITS!")
else:
    print("LOAD TEST SAMPLES...")
    test_generator = test_datagen.flow_from_directory(
                TEST_DATA_DIR,
                target_size=IMAGE_SIZE,
                batch_size=BATCH_SIZE,
                class_mode='categorical',
                seed=42,
                shuffle=False)

    #CHECK  THE NUMBER OF SAMPLES
    nb_test_samples = len(test_generator.filenames)
    if nb_test_samples == 0:
        print("NO DATA TEST FOUND IN TEST FOLDER!")
# Out:
# LOAD VALIDATION SAMPLES...
# Found 1194 images belonging to 199 classes.
#
# LOAD TEST SAMPLES...
# Found 796 images belonging to 199 classes.

# %% [markdown]
# # **ENSEMBLE MODEL ABLATIONS**

# %%
TOTAL_CLASSES = 199
LEARNING_RATE = 0.001
OPTIMIZER = Adam
BATCH_SIZE = 4
EPOCHS = 30
DROPOUT_RATE = 0.5

print("HYPERPARAMETERS")
print("---------------------")
print("BATCH_SIZE -->", BATCH_SIZE)
print("EPOCHS SET -->", EPOCHS)
print("DROPOUT_RATE -->", DROPOUT_RATE)
print("LEARNING_RATE -->", LEARNING_RATE)
print("OPTIMIZER -->", OPTIMIZER.__name__)
# Out:
# HYPERPARAMETERS
# ---------------------
# BATCH_SIZE --> 4
# EPOCHS SET --> 30
# DROPOUT_RATE --> 0.5
# LEARNING_RATE --> 0.001
# OPTIMIZER --> Adam

# %%
import itertools
import time

n = 2
i = 1
max_val_acc = 0
best_ablation = None

start_time = time.time()

print("The following models are to be ensembled")
print()
print(ENSEMBLE_FILES)

while(n <= len(ENSEMBLE_FILES)):
    for to_ensemble in list(itertools.combinations(ENSEMBLE_FILES, n)):
        print()
        print("Current Ablation number", str(i) + " :", to_ensemble)
        model = get_ensemble(teacher_models, to_ensemble)
        model.compile(
            optimizer=Adam(learning_rate=LEARNING_RATE),
            loss = CategoricalCrossentropy(from_logits=True),
            metrics=['accuracy']
        )
        acc = model.evaluate(validation_generator)[1]
        if max_val_acc < acc:
            max_val_acc = acc
            best_ablation = to_ensemble

        i += 1
    n += 1

elapsed_time = time.time() - start_time
train_time = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))

print()
print()
print(train_time, 'elapsed time')
print()
print(elapsed_time, 'seconds')
print()
print("Best Ablation:", best_ablation)
print("Highest Accuracy:", max_val_acc)
print("Total ablations built:", n)
# Out:
# The following models are to be ensembled
#
# ['EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0']
#
# Current Ablation number 1 : ('EfficientNetB7', 'DenseNet201')
# 299/299 [==============================] - 34s 90ms/step - loss: 4.4121 - accuracy: 0.9246
#
# Current Ablation number 2 : ('EfficientNetB7', 'DenseNet121')
# 299/299 [==============================] - 31s 80ms/step - loss: 4.4326 - accuracy: 0.9079
#
# Current Ablation number 3 : ('EfficientNetB7', 'InceptionResNetV2')
# 299/299 [==============================] - 38s 99ms/step - loss: 4.4215 - accuracy: 0.9154
#
# Current Ablation number 4 : ('EfficientNetB7', 'InceptionV3')
# 299/299 [==============================] - 30s 78ms/step - loss: 4.4260 - accuracy: 0.9179
#
# Current Ablation number 5 : ('EfficientNetB7', 'NASNetLarge')
# 299/299 [==============================] - 44s 115ms/step - loss: 4.4273 - accuracy: 0.9137
#
# Current Ablation number 6 : ('EfficientNetB7', 'EfficientNetB0')
# 299/299 [==============================] - 28s 72ms/step - loss: 4.4457 - accuracy: 0.9087
#
# Current Ablation number 7 : ('DenseNet201', 'DenseNet121')
# 299/299 [==============================] - 22s 59ms/step - loss: 4.4264 - accuracy: 0.9162
#
# Current Ablation number 8 : ('DenseNet201', 'InceptionResNetV2')
# 299/299 [==============================] - 30s 81ms/step - loss: 4.4153 - accuracy: 0.9129
#
# Current Ablation number 9 : ('DenseNet201', 'InceptionV3')
# 299/299 [==============================] - 21s 57ms/step - loss: 4.4198 - accuracy: 0.9129
#
# Current Ablation number 10 : ('DenseNet201', 'NASNetLarge')
# 299/299 [==============================] - 35s 91ms/step - loss: 4.4210 - accuracy: 0.9179
#
# Current Ablation number 11 : ('DenseNet201', 'EfficientNetB0')
# 299/299 [==============================] - 19s 51ms/step - loss: 4.4394 - accuracy: 0.9146
#
# Current Ablation number 12 : ('DenseNet121', 'InceptionResNetV2')
# 299/299 [==============================] - 26s 67ms/step - loss: 4.4358 - accuracy: 0.9037
#
# Current Ablation number 13 : ('DenseNet121', 'InceptionV3')
# 299/299 [==============================] - 15s 42ms/step - loss: 4.4403 - accuracy: 0.9121
#
# Current Ablation number 14 : ('DenseNet121', 'NASNetLarge')
# 299/299 [==============================] - 31s 79ms/step - loss: 4.4416 - accuracy: 0.9003
#
# Current Ablation number 15 : ('DenseNet121', 'EfficientNetB0')
# 299/299 [==============================] - 16s 40ms/step - loss: 4.4600 - accuracy: 0.9062
#
# Current Ablation number 16 : ('InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 24s 66ms/step - loss: 4.4292 - accuracy: 0.9112
#
# Current Ablation number 17 : ('InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 38s 100ms/step - loss: 4.4304 - accuracy: 0.9104
#
# Current Ablation number 18 : ('InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 22s 61ms/step - loss: 4.4488 - accuracy: 0.8961
#
# Current Ablation number 19 : ('InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 32s 85ms/step - loss: 4.4349 - accuracy: 0.9104
#
# Current Ablation number 20 : ('InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 14s 38ms/step - loss: 4.4533 - accuracy: 0.9020
#
# Current Ablation number 21 : ('NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 31s 75ms/step - loss: 4.4546 - accuracy: 0.9028
#
# Current Ablation number 22 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121')
# 299/299 [==============================] - 43s 111ms/step - loss: 4.4237 - accuracy: 0.9280
#
# Current Ablation number 23 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2')
# 299/299 [==============================] - 50s 129ms/step - loss: 4.4163 - accuracy: 0.9246
#
# Current Ablation number 24 : ('EfficientNetB7', 'DenseNet201', 'InceptionV3')
# 299/299 [==============================] - 43s 108ms/step - loss: 4.4193 - accuracy: 0.9229
#
# Current Ablation number 25 : ('EfficientNetB7', 'DenseNet201', 'NASNetLarge')
# 299/299 [==============================] - 57s 145ms/step - loss: 4.4201 - accuracy: 0.9288
#
# Current Ablation number 26 : ('EfficientNetB7', 'DenseNet201', 'EfficientNetB0')
# 299/299 [==============================] - 42s 105ms/step - loss: 4.4324 - accuracy: 0.9238
#
# Current Ablation number 27 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2')
# 299/299 [==============================] - 46s 121ms/step - loss: 4.4299 - accuracy: 0.9204
#
# Current Ablation number 28 : ('EfficientNetB7', 'DenseNet121', 'InceptionV3')
# 299/299 [==============================] - 36s 93ms/step - loss: 4.4329 - accuracy: 0.9229
#
# Current Ablation number 29 : ('EfficientNetB7', 'DenseNet121', 'NASNetLarge')
# 299/299 [==============================] - 53s 133ms/step - loss: 4.4338 - accuracy: 0.9246
#
# Current Ablation number 30 : ('EfficientNetB7', 'DenseNet121', 'EfficientNetB0')
# 299/299 [==============================] - 35s 91ms/step - loss: 4.4461 - accuracy: 0.9196
#
# Current Ablation number 31 : ('EfficientNetB7', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 48s 120ms/step - loss: 4.4255 - accuracy: 0.9171
#
# Current Ablation number 32 : ('EfficientNetB7', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 62s 157ms/step - loss: 4.4264 - accuracy: 0.9188
#
# Current Ablation number 33 : ('EfficientNetB7', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 47s 115ms/step - loss: 4.4386 - accuracy: 0.9154
#
# Current Ablation number 34 : ('EfficientNetB7', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 54s 138ms/step - loss: 4.4294 - accuracy: 0.9196
#
# Current Ablation number 35 : ('EfficientNetB7', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 35s 92ms/step - loss: 4.4416 - accuracy: 0.9079
#
# Current Ablation number 36 : ('EfficientNetB7', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 52s 132ms/step - loss: 4.4425 - accuracy: 0.9188
#
# Current Ablation number 37 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2')
# 299/299 [==============================] - 40s 103ms/step - loss: 4.4258 - accuracy: 0.9154
#
# Current Ablation number 38 : ('DenseNet201', 'DenseNet121', 'InceptionV3')
# 299/299 [==============================] - 33s 82ms/step - loss: 4.4288 - accuracy: 0.9196
#
# Current Ablation number 39 : ('DenseNet201', 'DenseNet121', 'NASNetLarge')
# 299/299 [==============================] - 46s 115ms/step - loss: 4.4296 - accuracy: 0.9271
#
# Current Ablation number 40 : ('DenseNet201', 'DenseNet121', 'EfficientNetB0')
# 299/299 [==============================] - 30s 77ms/step - loss: 4.4419 - accuracy: 0.9171
#
# Current Ablation number 41 : ('DenseNet201', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 42s 104ms/step - loss: 4.4214 - accuracy: 0.9179
#
# Current Ablation number 42 : ('DenseNet201', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 54s 136ms/step - loss: 4.4222 - accuracy: 0.9204
#
# Current Ablation number 43 : ('DenseNet201', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 39s 100ms/step - loss: 4.4345 - accuracy: 0.9162
#
# Current Ablation number 44 : ('DenseNet201', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 46s 109ms/step - loss: 4.4252 - accuracy: 0.9255
#
# Current Ablation number 45 : ('DenseNet201', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 29s 75ms/step - loss: 4.4375 - accuracy: 0.9137
#
# Current Ablation number 46 : ('DenseNet201', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 43s 106ms/step - loss: 4.4383 - accuracy: 0.9213
#
# Current Ablation number 47 : ('DenseNet121', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 34s 91ms/step - loss: 4.4350 - accuracy: 0.9137
#
# Current Ablation number 48 : ('DenseNet121', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 48s 122ms/step - loss: 4.4359 - accuracy: 0.9137
#
# Current Ablation number 49 : ('DenseNet121', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 33s 86ms/step - loss: 4.4481 - accuracy: 0.9079
#
# Current Ablation number 50 : ('DenseNet121', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 39s 98ms/step - loss: 4.4389 - accuracy: 0.9196
#
# Current Ablation number 51 : ('DenseNet121', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 22s 59ms/step - loss: 4.4512 - accuracy: 0.9137
#
# Current Ablation number 52 : ('DenseNet121', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 38s 95ms/step - loss: 4.4520 - accuracy: 0.9146
#
# Current Ablation number 53 : ('InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 50s 120ms/step - loss: 4.4315 - accuracy: 0.9179
#
# Current Ablation number 54 : ('InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 32s 85ms/step - loss: 4.4437 - accuracy: 0.9095
#
# Current Ablation number 55 : ('InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 48s 119ms/step - loss: 4.4446 - accuracy: 0.9104
#
# Current Ablation number 56 : ('InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 38s 91ms/step - loss: 4.4476 - accuracy: 0.9070
#
# Current Ablation number 57 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2')
# 299/299 [==============================] - 63s 161ms/step - loss: 4.4239 - accuracy: 0.9196
#
# Current Ablation number 58 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionV3')
# 299/299 [==============================] - 55s 133ms/step - loss: 4.4262 - accuracy: 0.9305
#
# Current Ablation number 59 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'NASNetLarge')
# 299/299 [==============================] - 69s 170ms/step - loss: 4.4268 - accuracy: 0.9330
#
# Current Ablation number 60 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'EfficientNetB0')
# 299/299 [==============================] - 52s 128ms/step - loss: 4.4360 - accuracy: 0.9271
#
# Current Ablation number 61 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 62s 160ms/step - loss: 4.4206 - accuracy: 0.9296
#
# Current Ablation number 62 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 79s 197ms/step - loss: 4.4212 - accuracy: 0.9322
#
# Current Ablation number 63 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 60s 148ms/step - loss: 4.4304 - accuracy: 0.9213
#
# Current Ablation number 64 : ('EfficientNetB7', 'DenseNet201', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 67s 167ms/step - loss: 4.4235 - accuracy: 0.9363
#
# Current Ablation number 65 : ('EfficientNetB7', 'DenseNet201', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 53s 125ms/step - loss: 4.4327 - accuracy: 0.9246
#
# Current Ablation number 66 : ('EfficientNetB7', 'DenseNet201', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 65s 164ms/step - loss: 4.4333 - accuracy: 0.9263
#
# Current Ablation number 67 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 55s 140ms/step - loss: 4.4308 - accuracy: 0.9196
#
# Current Ablation number 68 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 73s 176ms/step - loss: 4.4315 - accuracy: 0.9204
#
# Current Ablation number 69 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 53s 134ms/step - loss: 4.4407 - accuracy: 0.9188
#
# Current Ablation number 70 : ('EfficientNetB7', 'DenseNet121', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 66s 159ms/step - loss: 4.4337 - accuracy: 0.9280
#
# Current Ablation number 71 : ('EfficientNetB7', 'DenseNet121', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 44s 113ms/step - loss: 4.4429 - accuracy: 0.9196
#
# Current Ablation number 72 : ('EfficientNetB7', 'DenseNet121', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 61s 149ms/step - loss: 4.4436 - accuracy: 0.9213
#
# Current Ablation number 73 : ('EfficientNetB7', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 76s 179ms/step - loss: 4.4281 - accuracy: 0.9263
#
# Current Ablation number 74 : ('EfficientNetB7', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 54s 138ms/step - loss: 4.4373 - accuracy: 0.9204
#
# Current Ablation number 75 : ('EfficientNetB7', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 72s 177ms/step - loss: 4.4380 - accuracy: 0.9238s - loss: 4.4370 - accuracy
#
# Current Ablation number 76 : ('EfficientNetB7', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 66s 152ms/step - loss: 4.4402 - accuracy: 0.9213
#
# Current Ablation number 77 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 51s 131ms/step - loss: 4.4277 - accuracy: 0.9171
#
# Current Ablation number 78 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 66s 164ms/step - loss: 4.4284 - accuracy: 0.9238
#
# Current Ablation number 79 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 49s 124ms/step - loss: 4.4376 - accuracy: 0.9171
#
# Current Ablation number 80 : ('DenseNet201', 'DenseNet121', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 58s 132ms/step - loss: 4.4306 - accuracy: 0.9296
#
# Current Ablation number 81 : ('DenseNet201', 'DenseNet121', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 39s 100ms/step - loss: 4.4398 - accuracy: 0.9221
#
# Current Ablation number 82 : ('DenseNet201', 'DenseNet121', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 52s 126ms/step - loss: 4.4404 - accuracy: 0.9255
#
# Current Ablation number 83 : ('DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 66s 156ms/step - loss: 4.4250 - accuracy: 0.9255
#
# Current Ablation number 84 : ('DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 46s 119ms/step - loss: 4.4342 - accuracy: 0.9154
#
# Current Ablation number 85 : ('DenseNet201', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 62s 152ms/step - loss: 4.4349 - accuracy: 0.9263
#
# Current Ablation number 86 : ('DenseNet201', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 54s 124ms/step - loss: 4.4371 - accuracy: 0.9246
#
# Current Ablation number 87 : ('DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 57s 145ms/step - loss: 4.4353 - accuracy: 0.9221
#
# Current Ablation number 88 : ('DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 41s 108ms/step - loss: 4.4445 - accuracy: 0.9146
#
# Current Ablation number 89 : ('DenseNet121', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 57s 141ms/step - loss: 4.4451 - accuracy: 0.9154
#
# Current Ablation number 90 : ('DenseNet121', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 49s 112ms/step - loss: 4.4474 - accuracy: 0.9188
#
# Current Ablation number 91 : ('InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 54s 137ms/step - loss: 4.4418 - accuracy: 0.9221
#
# Current Ablation number 92 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3')
# 299/299 [==============================] - 74s 186ms/step - loss: 4.4258 - accuracy: 0.9288
#
# Current Ablation number 93 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge')
# 299/299 [==============================] - 90s 211ms/step - loss: 4.4263 - accuracy: 0.9322
#
# Current Ablation number 94 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'EfficientNetB0')
# 299/299 [==============================] - 71s 176ms/step - loss: 4.4337 - accuracy: 0.9255
#
# Current Ablation number 95 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 81s 189ms/step - loss: 4.4281 - accuracy: 0.9380
#
# Current Ablation number 96 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 59s 148ms/step - loss: 4.4355 - accuracy: 0.9271
#
# Current Ablation number 97 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 77s 186ms/step - loss: 4.4360 - accuracy: 0.9296
#
# Current Ablation number 98 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 88s 202ms/step - loss: 4.4237 - accuracy: 0.9288
#
# Current Ablation number 99 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 70s 173ms/step - loss: 4.4310 - accuracy: 0.9288
#
# Current Ablation number 100 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 89s 215ms/step - loss: 4.4315 - accuracy: 0.9305
#
# Current Ablation number 101 : ('EfficientNetB7', 'DenseNet201', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 81s 185ms/step - loss: 4.4333 - accuracy: 0.9322
#
# Current Ablation number 102 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 82s 201ms/step - loss: 4.4319 - accuracy: 0.9255
#
# Current Ablation number 103 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 64s 158ms/step - loss: 4.4392 - accuracy: 0.9238
#
# Current Ablation number 104 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 85s 197ms/step - loss: 4.4397 - accuracy: 0.9238
#
# Current Ablation number 105 : ('EfficientNetB7', 'DenseNet121', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 68s 164ms/step - loss: 4.4415 - accuracy: 0.9271
#
# Current Ablation number 106 : ('EfficientNetB7', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 79s 190ms/step - loss: 4.4371 - accuracy: 0.9238
#
# Current Ablation number 107 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 77s 173ms/step - loss: 4.4294 - accuracy: 0.9263
#
# Current Ablation number 108 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 58s 144ms/step - loss: 4.4368 - accuracy: 0.9171
#
# Current Ablation number 109 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 73s 175ms/step - loss: 4.4373 - accuracy: 0.9246
#
# Current Ablation number 110 : ('DenseNet201', 'DenseNet121', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 62s 147ms/step - loss: 4.4391 - accuracy: 0.9280
#
# Current Ablation number 111 : ('DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 72s 176ms/step - loss: 4.4346 - accuracy: 0.9229
#
# Current Ablation number 112 : ('DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 64s 157ms/step - loss: 4.4428 - accuracy: 0.9213
#
# Current Ablation number 113 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge')
# 299/299 [==============================] - 101s 241ms/step - loss: 4.4275 - accuracy: 0.9313
#
# Current Ablation number 114 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'EfficientNetB0')
# 299/299 [==============================] - 80s 196ms/step - loss: 4.4337 - accuracy: 0.9263
#
# Current Ablation number 115 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 97s 229ms/step - loss: 4.4341 - accuracy: 0.9288
#
# Current Ablation number 116 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 94s 208ms/step - loss: 4.4356 - accuracy: 0.9355
#
# Current Ablation number 117 : ('EfficientNetB7', 'DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 98s 235ms/step - loss: 4.4319 - accuracy: 0.9280
#
# Current Ablation number 118 : ('EfficientNetB7', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 93s 222ms/step - loss: 4.4387 - accuracy: 0.9246
#
# Current Ablation number 119 : ('DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 87s 190ms/step - loss: 4.4366 - accuracy: 0.9271
#
# Current Ablation number 120 : ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionResNetV2', 'InceptionV3', 'NASNetLarge', 'EfficientNetB0')
# 299/299 [==============================] - 106s 253ms/step - loss: 4.4340 - accuracy: 0.9305
#
#
# 01:52:27 elapsed time
#
# 6747.083862543106 seconds
#
# Best Ablation: ('EfficientNetB7', 'DenseNet201', 'DenseNet121', 'InceptionV3', 'NASNetLarge')
# Highest Accuracy: 0.9380234479904175
# Total ablations built: 8

# %%
#EVALUATION OF BEST ABLATION
teacher_ensemble = get_ensemble(teacher_models, best_ablation)
teacher_ensemble.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss = CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

teacher_ensemble.summary()
# Out:
# Model: "teacher_model-EnsembleModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ensemble_input (InputLayer)     [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# tf.image.resize_449_EfficientNe (None, 224, 224, 3)  0           ensemble_input[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_450_DenseNet201 (None, 224, 224, 3)  0           ensemble_input[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_451_DenseNet121 (None, 224, 224, 3)  0           ensemble_input[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_452_InceptionV3 (None, 224, 224, 3)  0           ensemble_input[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_453_NASNetLarge (None, 224, 224, 3)  0           ensemble_input[0][0]
# __________________________________________________________________________________________________
# preprocess_EfficientNetB7 (EN_P (None, 224, 224, 3)  0           tf.image.resize_449_EfficientNetB
# __________________________________________________________________________________________________
# preprocess_DenseNet201 (Dense_P (None, 224, 224, 3)  0           tf.image.resize_450_DenseNet201[0
# __________________________________________________________________________________________________
# preprocess_DenseNet121 (Dense_P (None, 224, 224, 3)  0           tf.image.resize_451_DenseNet121[0
# __________________________________________________________________________________________________
# preprocess_InceptionV3 (INV3_Pr (None, 224, 224, 3)  0           tf.image.resize_452_InceptionV3[0
# __________________________________________________________________________________________________
# preprocess_NASNetLarge (NN_Prep (None, 224, 224, 3)  0           tf.image.resize_453_NASNetLarge[0
# __________________________________________________________________________________________________
# benchmark-onelayeroff-0_0001-Ef (None, 199)          64607326    preprocess_EfficientNetB7[0][0]
# __________________________________________________________________________________________________
# benchmark-onelayeroff-0_0001-De (None, 199)          18704263    preprocess_DenseNet201[0][0]
# __________________________________________________________________________________________________
# benchmark-onelayeroff-0_0001-De (None, 199)          7241479     preprocess_DenseNet121[0][0]
# __________________________________________________________________________________________________
# benchmark-onelayeroff-0_0001-In (None, 199)          22210535    preprocess_InceptionV3[0][0]
# __________________________________________________________________________________________________
# benchmark-onelayeroff-0_0001-NA (None, 199)          85719385    preprocess_NASNetLarge[0][0]
# __________________________________________________________________________________________________
# average_124 (Average)           (None, 199)          0           benchmark-onelayeroff-0_0001-Effi
#                                                                  benchmark-onelayeroff-0_0001-Dens
#                                                                  benchmark-onelayeroff-0_0001-Dens
#                                                                  benchmark-onelayeroff-0_0001-Ince
#                                                                  benchmark-onelayeroff-0_0001-NASN
# ==================================================================================================
# Total params: 198,482,988
# Trainable params: 197,628,457
# Non-trainable params: 854,531
# __________________________________________________________________________________________________

# %%
print("Evaluation on Validation Set")
acc = teacher_ensemble.evaluate(validation_generator)

print("Evaluation on Test Set")
acc = teacher_ensemble.evaluate(test_generator)
# Out:
# Evaluation on Validation Set
# 299/299 [==============================] - 86s 201ms/step - loss: 4.4281 - accuracy: 0.9380
# Evaluation on Test Set
# 199/199 [==============================] - 40s 200ms/step - loss: 4.4158 - accuracy: 0.9259

# %%
#save model
save_m(teacher_ensemble, TEACHER_MODEL_PATH + MODEL_NAME, MODEL_NAME)
print("[INFO] MODEL AND HISTORY SAVED to ", TEACHER_MODEL_PATH + 'TeacherEnsemble/')
# Out:
# c:\users\franc\anaconda3\envs\replicate\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# [INFO] MODEL AND HISTORY SAVED to  models/teacher_model/TeacherEnsemble/
