# %% [markdown]
# # **Importing libraries**

# %%
#Set path to MAIN FOLDER OF EXPERIMENT
#cd /path/to/EXPERIMENT_FOLDER/

# %%
#Import tensorflow and keras modules
from tensorflow.keras.layers import Dropout, Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model, save_model
from tensorflow.keras.optimizers import Adam
from keras.models import model_from_json
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pickle

# %%
#Save Model Function
def save_m(file, model):
    if not os.path.exists(file):
        os.makedirs(file)

    model.save_weights(file+'/model.h5')
    model_json = model.to_json()
    with open(file + "/model.json", "w") as json_file:
        json_file.write(model_json)

#Save History Function
def save_h(file, history):
    if not os.path.exists(file):
        os.makedirs(file)

    with open(file + '/' + 'model.history', 'wb') as file_pi:
        pickle.dump(history, file_pi)

#Load History Function
def load_h(file):
    with open(file + '/' + 'model.history', 'rb') as file_pi:
        his = pickle.load(file_pi)
    return his

# %% [markdown]
# # **Loading and Prepraring Data**

# %%
#Define Constants
IMAGE_SIZE = (256, 256)
MODEL_INPUT = Input(shape=(256, 256, 3))
BATCH_SIZE = 4
EPOCHS = 30
LEARNING_RATE = 0.0001

#Data paths
TRAIN_DATA_PATH = 'ds/train/'
VAL_DATA_PATH = 'ds/val/'
TEST_DATA_PATH = 'ds/test/'

#Model path
NORMAL_STUDENT_MODEL_PATH = 'models/Student_Models/'

# %%
#Create Generator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)

#Set Generator
train_generator = train_datagen.flow_from_directory(TRAIN_DATA_PATH, 
                                                    target_size=IMAGE_SIZE, 
                                                    batch_size=BATCH_SIZE, 
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(VAL_DATA_PATH, 
                                                        target_size=IMAGE_SIZE, 
                                                        batch_size=BATCH_SIZE, 
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(TEST_DATA_PATH, 
                                                  target_size=IMAGE_SIZE, 
                                                  batch_size=BATCH_SIZE, 
                                                  class_mode='categorical')

nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)
num_classes= len(train_generator.class_indices)

print('NUMBER OF TRAIN SAMPLES:', nb_train_samples)
print('NUMBER OF VALIDATION SAMPLES:',nb_validation_samples)
print('NUMBER OF TEST SAMPLES:',nb_test_samples)
print('TOTAL CLASSES:', num_classes)
# Out:
# Found 1990 images belonging to 199 classes.
# Found 1194 images belonging to 199 classes.
# Found 796 images belonging to 199 classes.
# NUMBER OF TRAIN SAMPLES: 1990
# NUMBER OF VALIDATION SAMPLES: 1194
# NUMBER OF TEST SAMPLES: 796
# TOTAL CLASSES: 199

# %% [markdown]
# # **Training**

# %% [markdown]
# **Using EfficientNetB0**

# %%
#Load pretrained model
from tensorflow.keras.applications import EfficientNetB0
transfer = EfficientNetB0(include_top = False, weights = 'imagenet',input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))

model = tf.keras.Sequential([
    transfer,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(199)
])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb0 (Functional)  (None, 8, 8, 1280)        4049571
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 199)               254919
# =================================================================
# Total params: 4,304,490
# Trainable params: 4,262,467
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
#Start Training
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=2,
                              verbose=1, mode='max', min_lr=0.000001)

callbacks = [reduce_lr]

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss = CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history = model.fit(
        train_generator,
        epochs=EPOCHS,
        callbacks=callbacks,
        steps_per_epoch = nb_train_samples  // BATCH_SIZE,
        validation_steps = nb_validation_samples // BATCH_SIZE,
        validation_data = validation_generator
)
# Out:
# Epoch 1/30
# 497/497 [==============================] - 61s 108ms/step - loss: 5.3249 - accuracy: 0.0076 - val_loss: 4.9529 - val_accuracy: 0.0814
# Epoch 2/30
# 497/497 [==============================] - 52s 105ms/step - loss: 4.7708 - accuracy: 0.1043 - val_loss: 4.3293 - val_accuracy: 0.1963
# Epoch 3/30
# 497/497 [==============================] - 52s 105ms/step - loss: 3.8486 - accuracy: 0.2897 - val_loss: 2.7282 - val_accuracy: 0.4807
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 4/30
# 497/497 [==============================] - 52s 106ms/step - loss: 2.9662 - accuracy: 0.5342 - val_loss: 2.2708 - val_accuracy: 0.5654
# Epoch 5/30
# 497/497 [==============================] - 52s 105ms/step - loss: 2.4312 - accuracy: 0.6609 - val_loss: 1.9345 - val_accuracy: 0.6317
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 6/30
# 497/497 [==============================] - 52s 105ms/step - loss: 2.0179 - accuracy: 0.7684 - val_loss: 1.7534 - val_accuracy: 0.6686
# Epoch 7/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.8152 - accuracy: 0.8038 - val_loss: 1.6196 - val_accuracy: 0.6787
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 8/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.6548 - accuracy: 0.8209 - val_loss: 1.4765 - val_accuracy: 0.7131
# Epoch 9/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.5380 - accuracy: 0.8535 - val_loss: 1.4628 - val_accuracy: 0.7173
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 10/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.4616 - accuracy: 0.8647 - val_loss: 1.4238 - val_accuracy: 0.7173
# Epoch 11/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.4623 - accuracy: 0.8355 - val_loss: 1.3767 - val_accuracy: 0.7273
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 12/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.3816 - accuracy: 0.8795 - val_loss: 1.3652 - val_accuracy: 0.7290
# Epoch 13/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.3873 - accuracy: 0.8633 - val_loss: 1.3276 - val_accuracy: 0.7299
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 14/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.3614 - accuracy: 0.8710 - val_loss: 1.3272 - val_accuracy: 0.7315
# Epoch 15/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.3533 - accuracy: 0.8796 - val_loss: 1.3273 - val_accuracy: 0.7307
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 16/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.3226 - accuracy: 0.8727 - val_loss: 1.3091 - val_accuracy: 0.7408
# Epoch 17/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.3055 - accuracy: 0.8851 - val_loss: 1.3028 - val_accuracy: 0.7374
# Epoch 18/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.3545 - accuracy: 0.8731 - val_loss: 1.3103 - val_accuracy: 0.7307
# Epoch 19/30
# 497/497 [==============================] - 53s 107ms/step - loss: 1.3448 - accuracy: 0.8734 - val_loss: 1.3142 - val_accuracy: 0.7324
# Epoch 20/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2926 - accuracy: 0.8919 - val_loss: 1.2998 - val_accuracy: 0.7324
# Epoch 21/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2886 - accuracy: 0.8954 - val_loss: 1.2879 - val_accuracy: 0.7332
# Epoch 22/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.2918 - accuracy: 0.8885 - val_loss: 1.2688 - val_accuracy: 0.7383
# Epoch 23/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2863 - accuracy: 0.9015 - val_loss: 1.2710 - val_accuracy: 0.7433
# Epoch 24/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2971 - accuracy: 0.8844 - val_loss: 1.2998 - val_accuracy: 0.7307
# Epoch 25/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.2786 - accuracy: 0.8870 - val_loss: 1.2732 - val_accuracy: 0.7357
# Epoch 26/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2474 - accuracy: 0.8978 - val_loss: 1.2755 - val_accuracy: 0.7391
# Epoch 27/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.2927 - accuracy: 0.8788 - val_loss: 1.2479 - val_accuracy: 0.7441
# Epoch 28/30
# 497/497 [==============================] - 53s 106ms/step - loss: 1.2533 - accuracy: 0.9002 - val_loss: 1.2919 - val_accuracy: 0.7416
# Epoch 29/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.2602 - accuracy: 0.8863 - val_loss: 1.2546 - val_accuracy: 0.7458
# Epoch 30/30
# 497/497 [==============================] - 52s 105ms/step - loss: 1.1999 - accuracy: 0.8994 - val_loss: 1.2455 - val_accuracy: 0.7383

# %%
#testing
acc = model.evaluate(test_generator)
# Out:
# 199/199 [==============================] - 6s 32ms/step - loss: 1.2851 - accuracy: 0.7073

# %%
print("MODEL AND HISTORY SAVED")
#save model
save_m(NORMAL_STUDENT_MODEL_PATH + 'EfficientNetB0', model)
#save history
save_h(NORMAL_STUDENT_MODEL_PATH + 'EfficientNetB0', history.history)
# Out:
# MODEL AND HISTORY SAVED

# %% [markdown]
# # **Training Visualization**

# %%
#VISUAL CUSTOMIZER
distiller_history = load_h(NORMAL_STUDENT_MODEL_PATH + 'EfficientNetB0')

marker_t = '^'
marker_v = '+'
market_t_loss = 'v'
market_v_loss = 'x'
markersize = 5
fillstyle_t = 'none'
fillstyle_v = 'none'

color_t = 'blue'
color_v = 'orange'

labelsize = 10
fontsize = 7

color_t_loss = 'green'
color_v_loss = 'red'

border_pad = 0.5
legend_font_size = 9

ls_t = '-' 
ls_v = '--'
lw_t = '1.5'
lw_v = '1.5'

print("You may change the values if needed for the ease of your evaluation")
# Out:
# You may change the values if needed for the ease of your evaluation

# %% [markdown]
# **Accuracy Curve**

# %%
#PRINTS THE ACCURACY GROWTH
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300, edgecolor='black', facecolor='white', linewidth=0)
plt.tight_layout()

plt.gcf().subplots_adjust(bottom=0.15)

plt.rc('xtick',labelsize=labelsize, direction="in") 
plt.rc('ytick', labelsize=labelsize, direction="in") 
plt.tick_params(length=4, right=True, top=True)

plt.plot(np.arange(1, N+1), distiller_history["accuracy"], color=color_t,lw=lw_t, marker=marker_t, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Accuracy")
plt.plot(np.arange(1, N+1), distiller_history["val_accuracy"], color=color_v ,lw=lw_v, marker=marker_v, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v,  label="Validation Accuracy")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Accuracy", fontsize=fontsize, color='black')
plt.legend(loc="lower right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()

# %% [markdown]
# **Loss Curve**

# %%
#PRINTS THE DECREASE OF LOSS
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300)
plt.plot(np.arange(1, N+1), distiller_history["loss"], color=color_t_loss,lw=lw_t, marker=market_t_loss, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Loss")
plt.plot(np.arange(1, N+1), distiller_history["val_loss"], color=color_v_loss,lw=lw_v, marker=market_v_loss, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v, label="Validation Loss")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Loss", fontsize=fontsize, color='black')
plt.legend(loc="upper right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()
