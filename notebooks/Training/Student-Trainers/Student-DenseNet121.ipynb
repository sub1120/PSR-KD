# %% [markdown]
# # **Importing libraries**

# %%
#Set path to MAIN FOLDER OF EXPERIMENT
#cd /path/to/EXPERIMENT_FOLDER/

# %%
#Import tensorflow and keras modules
from tensorflow.keras.layers import Dropout, Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model, save_model
from tensorflow.keras.optimizers import Adam
from keras.models import model_from_json
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pickle

# %%
#Save Model Function
def save_m(file, model):
    if not os.path.exists(file):
        os.makedirs(file)

    model.save_weights(file+'/model.h5')
    model_json = model.to_json()
    with open(file + "/model.json", "w") as json_file:
        json_file.write(model_json)

#Save History Function
def save_h(file, history):
    if not os.path.exists(file):
        os.makedirs(file)

    with open(file + '/' + 'model.history', 'wb') as file_pi:
        pickle.dump(history, file_pi)

#Load History Function
def load_h(file):
    with open(file + '/' + 'model.history', 'rb') as file_pi:
        his = pickle.load(file_pi)
    return his

# %% [markdown]
# # **Loading and Prepraring Data**

# %%
#Define Constants
IMAGE_SIZE = (256, 256)
MODEL_INPUT = Input(shape=(256, 256, 3))
BATCH_SIZE = 4
EPOCHS = 30
LEARNING_RATE = 0.0001

#Data paths
TRAIN_DATA_PATH = 'ds/train/'
VAL_DATA_PATH = 'ds/val/'
TEST_DATA_PATH = 'ds/test/'

#Model path
NORMAL_STUDENT_MODEL_PATH = 'models/Student_Models/'

# %%
#Create Generator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)

#Set Generator
train_generator = train_datagen.flow_from_directory(TRAIN_DATA_PATH, 
                                                    target_size=IMAGE_SIZE, 
                                                    batch_size=BATCH_SIZE, 
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(VAL_DATA_PATH, 
                                                        target_size=IMAGE_SIZE, 
                                                        batch_size=BATCH_SIZE, 
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(TEST_DATA_PATH, 
                                                  target_size=IMAGE_SIZE, 
                                                  batch_size=BATCH_SIZE, 
                                                  class_mode='categorical')

nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)
num_classes= len(train_generator.class_indices)

print('NUMBER OF TRAIN SAMPLES:', nb_train_samples)
print('NUMBER OF VALIDATION SAMPLES:',nb_validation_samples)
print('NUMBER OF TEST SAMPLES:',nb_test_samples)
print('TOTAL CLASSES:', num_classes)
# Out:
# Found 1990 images belonging to 199 classes.
# Found 1194 images belonging to 199 classes.
# Found 796 images belonging to 199 classes.
# NUMBER OF TRAIN SAMPLES: 1990
# NUMBER OF VALIDATION SAMPLES: 1194
# NUMBER OF TEST SAMPLES: 796
# TOTAL CLASSES: 199

# %% [markdown]
# # **Training**

# %% [markdown]
# **Using DenseNet121**

# %%
#Load pretrained model
from tensorflow.keras.applications import DenseNet121
transfer = DenseNet121(include_top = False, weights = 'imagenet',input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))

model = tf.keras.Sequential([
    transfer,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(199)
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 8, 8, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 199)               203975
# =================================================================
# Total params: 7,241,479
# Trainable params: 7,157,831
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
#Start Training
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=2,
                              verbose=1, mode='max', min_lr=0.000001)

callbacks = [reduce_lr]

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss = CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history = model.fit(
        train_generator,
        epochs=EPOCHS,
        callbacks=callbacks,
        steps_per_epoch = nb_train_samples  // BATCH_SIZE,
        validation_steps = nb_validation_samples // BATCH_SIZE,
        validation_data = validation_generator
)
# Out:
# Epoch 1/30
# 497/497 [==============================] - 68s 117ms/step - loss: 5.8721 - accuracy: 0.0096 - val_loss: 4.7667 - val_accuracy: 0.0847
# Epoch 2/30
# 497/497 [==============================] - 55s 111ms/step - loss: 4.8527 - accuracy: 0.0469 - val_loss: 3.4321 - val_accuracy: 0.3574
# Epoch 3/30
# 497/497 [==============================] - 55s 112ms/step - loss: 3.7679 - accuracy: 0.2275 - val_loss: 2.4758 - val_accuracy: 0.5856
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 4/30
# 497/497 [==============================] - 55s 111ms/step - loss: 2.7446 - accuracy: 0.4768 - val_loss: 1.9309 - val_accuracy: 0.6988
# Epoch 5/30
# 497/497 [==============================] - 52s 105ms/step - loss: 2.1637 - accuracy: 0.6390 - val_loss: 1.5432 - val_accuracy: 0.7634
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 6/30
# 497/497 [==============================] - 54s 108ms/step - loss: 1.6726 - accuracy: 0.7939 - val_loss: 1.3638 - val_accuracy: 0.7886
# Epoch 7/30
# 497/497 [==============================] - 54s 108ms/step - loss: 1.3703 - accuracy: 0.8646 - val_loss: 1.1895 - val_accuracy: 0.8180
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 8/30
# 497/497 [==============================] - 53s 107ms/step - loss: 1.1957 - accuracy: 0.9078 - val_loss: 1.1213 - val_accuracy: 0.8305
# Epoch 9/30
# 497/497 [==============================] - 53s 108ms/step - loss: 1.0529 - accuracy: 0.9276 - val_loss: 1.0437 - val_accuracy: 0.8406
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 10/30
# 497/497 [==============================] - 53s 107ms/step - loss: 1.0242 - accuracy: 0.9240 - val_loss: 1.0242 - val_accuracy: 0.8389
# Epoch 11/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.9562 - accuracy: 0.9380 - val_loss: 0.9916 - val_accuracy: 0.8322
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 12/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.8783 - accuracy: 0.9440 - val_loss: 0.9610 - val_accuracy: 0.8364
# Epoch 13/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.8599 - accuracy: 0.9446 - val_loss: 0.9672 - val_accuracy: 0.8347
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 14/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.8410 - accuracy: 0.9490 - val_loss: 0.9492 - val_accuracy: 0.8431
# Epoch 15/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7724 - accuracy: 0.9714 - val_loss: 0.9581 - val_accuracy: 0.8389
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 16/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.8047 - accuracy: 0.9566 - val_loss: 0.9496 - val_accuracy: 0.8406
# Epoch 17/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7340 - accuracy: 0.9688 - val_loss: 0.9452 - val_accuracy: 0.8389
# Epoch 18/30
# 497/497 [==============================] - 54s 109ms/step - loss: 0.8048 - accuracy: 0.9563 - val_loss: 0.9414 - val_accuracy: 0.8414
# Epoch 19/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7645 - accuracy: 0.9619 - val_loss: 0.9336 - val_accuracy: 0.8423
# Epoch 20/30
# 497/497 [==============================] - 53s 107ms/step - loss: 0.7938 - accuracy: 0.9689 - val_loss: 0.9386 - val_accuracy: 0.8431
# Epoch 21/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7631 - accuracy: 0.9613 - val_loss: 0.9387 - val_accuracy: 0.8398
# Epoch 22/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7726 - accuracy: 0.9625 - val_loss: 0.9343 - val_accuracy: 0.8398
# Epoch 23/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7422 - accuracy: 0.9677 - val_loss: 0.9268 - val_accuracy: 0.8448
# Epoch 24/30
# 497/497 [==============================] - 54s 110ms/step - loss: 0.7286 - accuracy: 0.9700 - val_loss: 0.9242 - val_accuracy: 0.8423
# Epoch 25/30
# 497/497 [==============================] - 54s 109ms/step - loss: 0.7175 - accuracy: 0.9771 - val_loss: 0.9239 - val_accuracy: 0.8431
# Epoch 26/30
# 497/497 [==============================] - 53s 107ms/step - loss: 0.7349 - accuracy: 0.9619 - val_loss: 0.9103 - val_accuracy: 0.8482
# Epoch 27/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7027 - accuracy: 0.9721 - val_loss: 0.8983 - val_accuracy: 0.8465
# Epoch 28/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7348 - accuracy: 0.9706 - val_loss: 0.9075 - val_accuracy: 0.8456
# Epoch 29/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7298 - accuracy: 0.9671 - val_loss: 0.8972 - val_accuracy: 0.8465
# Epoch 30/30
# 497/497 [==============================] - 54s 108ms/step - loss: 0.7121 - accuracy: 0.9734 - val_loss: 0.8994 - val_accuracy: 0.8465

# %%
#testing
acc = model.evaluate(test_generator)

# %%
print("MODEL AND HISTORY SAVED")
#save model
save_m(NORMAL_STUDENT_MODEL_PATH + 'DenseNet121', model)
#save history
save_h(NORMAL_STUDENT_MODEL_PATH + 'DenseNet121', history.history)
# Out:
# MODEL AND HISTORY SAVED

# %% [markdown]
# # **Training Visualization**

# %%
#VISUAL CUSTOMIZER
distiller_history = load_h(NORMAL_STUDENT_MODEL_PATH + 'DenseNet121')

marker_t = '^'
marker_v = '+'
market_t_loss = 'v'
market_v_loss = 'x'
markersize = 5
fillstyle_t = 'none'
fillstyle_v = 'none'

color_t = 'blue'
color_v = 'orange'

labelsize = 10
fontsize = 7

color_t_loss = 'green'
color_v_loss = 'red'

border_pad = 0.5
legend_font_size = 9

ls_t = '-' 
ls_v = '--'
lw_t = '1.5'
lw_v = '1.5'

print("You may change the values if needed for the ease of your evaluation")
# Out:
# You may change the values if needed for the ease of your evaluation

# %% [markdown]
# **Accuracy Curve**

# %%
#PRINTS THE ACCURACY GROWTH
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300, edgecolor='black', facecolor='white', linewidth=0)
plt.tight_layout()

plt.gcf().subplots_adjust(bottom=0.15)

plt.rc('xtick',labelsize=labelsize, direction="in") 
plt.rc('ytick', labelsize=labelsize, direction="in") 
plt.tick_params(length=4, right=True, top=True)

plt.plot(np.arange(1, N+1), distiller_history["accuracy"], color=color_t,lw=lw_t, marker=marker_t, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Accuracy")
plt.plot(np.arange(1, N+1), distiller_history["val_accuracy"], color=color_v ,lw=lw_v, marker=marker_v, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v,  label="Validation Accuracy")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Accuracy", fontsize=fontsize, color='black')
plt.legend(loc="lower right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()

# %% [markdown]
# **Loss Curve**

# %%
#PRINTS THE DECREASE OF LOSS
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300)
plt.plot(np.arange(1, N+1), distiller_history["loss"], color=color_t_loss,lw=lw_t, marker=market_t_loss, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Loss")
plt.plot(np.arange(1, N+1), distiller_history["val_loss"], color=color_v_loss,lw=lw_v, marker=market_v_loss, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v, label="Validation Loss")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Loss", fontsize=fontsize, color='black')
plt.legend(loc="upper right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()
