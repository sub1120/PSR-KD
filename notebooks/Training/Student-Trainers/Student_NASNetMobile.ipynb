# %% [markdown]
# # **Importing libraries**

# %%
#Set path to MAIN FOLDER OF EXPERIMENT
#cd /path/to/EXPERIMENT_FOLDER/

# %%
#Import tensorflow and keras modules
from tensorflow.keras.layers import Dropout, Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.nasnet import preprocess_input
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model, save_model
from tensorflow.keras.optimizers import Adam
from keras.models import model_from_json
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pickle

# %%
#Save Model Function
def save_m(file, model):
    if not os.path.exists(file):
        os.makedirs(file)

    model.save_weights(file+'/model.h5')
    model_json = model.to_json()
    with open(file + "/model.json", "w") as json_file:
        json_file.write(model_json)

#Save History Function
def save_h(file, history):
    if not os.path.exists(file):
        os.makedirs(file)

    with open(file + '/' + 'model.history', 'wb') as file_pi:
        pickle.dump(history, file_pi)

#Load History Function
def load_h(file):
    with open(file + '/' + 'model.history', 'rb') as file_pi:
        his = pickle.load(file_pi)
    return his

# %% [markdown]
# # **Loading and Prepraring Data**

# %%
#Define Constants
IMAGE_SIZE = (256, 256)
MODEL_INPUT = Input(shape=(256, 256, 3))
BATCH_SIZE = 4
EPOCHS = 30
LEARNING_RATE = 0.0001

#Data paths
TRAIN_DATA_PATH = 'ds/train/'
VAL_DATA_PATH = 'ds/val/'
TEST_DATA_PATH = 'ds/test/'

#Model path
NORMAL_STUDENT_MODEL_PATH = 'models/Student_Models/'

# %%
#Create Generator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)

#Set Generator
train_generator = train_datagen.flow_from_directory(TRAIN_DATA_PATH, 
                                                    target_size=IMAGE_SIZE, 
                                                    batch_size=BATCH_SIZE, 
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(VAL_DATA_PATH, 
                                                        target_size=IMAGE_SIZE, 
                                                        batch_size=BATCH_SIZE, 
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(TEST_DATA_PATH, 
                                                  target_size=IMAGE_SIZE, 
                                                  batch_size=BATCH_SIZE, 
                                                  class_mode='categorical')

nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)
num_classes= len(train_generator.class_indices)

print('NUMBER OF TRAIN SAMPLES:', nb_train_samples)
print('NUMBER OF VALIDATION SAMPLES:',nb_validation_samples)
print('NUMBER OF TEST SAMPLES:',nb_test_samples)
print('TOTAL CLASSES:', num_classes)
# Out:
# Found 1990 images belonging to 199 classes.
# Found 1194 images belonging to 199 classes.
# Found 796 images belonging to 199 classes.
# NUMBER OF TRAIN SAMPLES: 1990
# NUMBER OF VALIDATION SAMPLES: 1194
# NUMBER OF TEST SAMPLES: 796
# TOTAL CLASSES: 199

# %% [markdown]
# # **Training**

# %% [markdown]
# **Using NASNetMobile**

# %%
#Load pretrained model
from tensorflow.keras.applications import NASNetMobile
transfer = NASNetMobile(include_top = False, weights = 'imagenet',input_tensor=MODEL_INPUT)

model = tf.keras.Sequential([
    transfer,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(199)
])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Functional)          (None, 8, 8, 1056)        4269716
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1056)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 199)               210343
# =================================================================
# Total params: 4,480,059
# Trainable params: 4,443,321
# Non-trainable params: 36,738
# _________________________________________________________________

# %%
#Start Training
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=2,
                              verbose=1, mode='max', min_lr=0.000001)

callbacks = [reduce_lr]

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss = CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history = model.fit(
        train_generator,
        epochs=EPOCHS,
        callbacks=callbacks,
        steps_per_epoch = nb_train_samples  // BATCH_SIZE,
        validation_steps = nb_validation_samples // BATCH_SIZE,
        validation_data = validation_generator
)
# Out:
# Epoch 1/30
# 497/497 [==============================] - 104s 178ms/step - loss: 5.3486 - accuracy: 0.0086 - val_loss: 5.4979 - val_accuracy: 0.0084
# Epoch 2/30
# 497/497 [==============================] - 84s 169ms/step - loss: 4.6757 - accuracy: 0.0871 - val_loss: 4.7268 - val_accuracy: 0.0721
# Epoch 3/30
# 497/497 [==============================] - 83s 167ms/step - loss: 3.1965 - accuracy: 0.2986 - val_loss: 3.8775 - val_accuracy: 0.1653
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 4/30
# 497/497 [==============================] - 85s 171ms/step - loss: 1.8584 - accuracy: 0.5645 - val_loss: 3.2364 - val_accuracy: 0.2919
# Epoch 5/30
# 497/497 [==============================] - 87s 175ms/step - loss: 1.1844 - accuracy: 0.7432 - val_loss: 2.6195 - val_accuracy: 0.4119
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 6/30
# 497/497 [==============================] - 84s 169ms/step - loss: 0.9000 - accuracy: 0.8147 - val_loss: 2.3791 - val_accuracy: 0.4723
# Epoch 7/30
# 497/497 [==============================] - 86s 173ms/step - loss: 0.7114 - accuracy: 0.8560 - val_loss: 2.1993 - val_accuracy: 0.4950
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 8/30
# 497/497 [==============================] - 83s 167ms/step - loss: 0.5779 - accuracy: 0.8857 - val_loss: 2.0201 - val_accuracy: 0.5453
# Epoch 9/30
# 497/497 [==============================] - 83s 168ms/step - loss: 0.5148 - accuracy: 0.8948 - val_loss: 1.8331 - val_accuracy: 0.5898
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 10/30
# 497/497 [==============================] - 84s 170ms/step - loss: 0.4628 - accuracy: 0.9169 - val_loss: 1.6687 - val_accuracy: 0.6191
# Epoch 11/30
# 497/497 [==============================] - 86s 173ms/step - loss: 0.4547 - accuracy: 0.9184 - val_loss: 1.5585 - val_accuracy: 0.6418
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 12/30
# 497/497 [==============================] - 85s 172ms/step - loss: 0.4488 - accuracy: 0.9194 - val_loss: 1.4724 - val_accuracy: 0.6560
# Epoch 13/30
# 497/497 [==============================] - 87s 176ms/step - loss: 0.4314 - accuracy: 0.9255 - val_loss: 1.4120 - val_accuracy: 0.6703
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 14/30
# 497/497 [==============================] - 83s 168ms/step - loss: 0.3881 - accuracy: 0.9320 - val_loss: 1.3452 - val_accuracy: 0.6812
# Epoch 15/30
# 497/497 [==============================] - 85s 172ms/step - loss: 0.4252 - accuracy: 0.9265 - val_loss: 1.2939 - val_accuracy: 0.6795
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 16/30
# 497/497 [==============================] - 93s 187ms/step - loss: 0.3890 - accuracy: 0.9350 - val_loss: 1.2606 - val_accuracy: 0.6888
# Epoch 17/30
# 497/497 [==============================] - 97s 196ms/step - loss: 0.4097 - accuracy: 0.9330 - val_loss: 1.2260 - val_accuracy: 0.6913
# Epoch 18/30
# 497/497 [==============================] - 97s 194ms/step - loss: 0.3832 - accuracy: 0.9371 - val_loss: 1.1928 - val_accuracy: 0.6971
# Epoch 19/30
# 497/497 [==============================] - 92s 186ms/step - loss: 0.3948 - accuracy: 0.9335 - val_loss: 1.1730 - val_accuracy: 0.7039
# Epoch 20/30
# 497/497 [==============================] - 93s 187ms/step - loss: 0.3916 - accuracy: 0.9295 - val_loss: 1.1539 - val_accuracy: 0.7081
# Epoch 21/30
# 497/497 [==============================] - 95s 191ms/step - loss: 0.3551 - accuracy: 0.9381 - val_loss: 1.1329 - val_accuracy: 0.7122
# Epoch 22/30
# 497/497 [==============================] - 94s 189ms/step - loss: 0.3561 - accuracy: 0.9421 - val_loss: 1.1235 - val_accuracy: 0.7139
# Epoch 23/30
# 497/497 [==============================] - 93s 188ms/step - loss: 0.3680 - accuracy: 0.9426 - val_loss: 1.1173 - val_accuracy: 0.7181
# Epoch 24/30
# 497/497 [==============================] - 93s 188ms/step - loss: 0.3792 - accuracy: 0.9366 - val_loss: 1.1048 - val_accuracy: 0.7190
# Epoch 25/30
# 497/497 [==============================] - 96s 193ms/step - loss: 0.3673 - accuracy: 0.9451 - val_loss: 1.0937 - val_accuracy: 0.7173
# Epoch 26/30
# 497/497 [==============================] - 96s 192ms/step - loss: 0.3757 - accuracy: 0.9381 - val_loss: 1.0922 - val_accuracy: 0.7164
# Epoch 27/30
# 497/497 [==============================] - 94s 189ms/step - loss: 0.3363 - accuracy: 0.9431 - val_loss: 1.0872 - val_accuracy: 0.7215
# Epoch 28/30
# 497/497 [==============================] - 95s 190ms/step - loss: 0.3612 - accuracy: 0.9431 - val_loss: 1.0825 - val_accuracy: 0.7206
# Epoch 29/30
# 497/497 [==============================] - 96s 193ms/step - loss: 0.3431 - accuracy: 0.9436 - val_loss: 1.0783 - val_accuracy: 0.7223
# Epoch 30/30
# 497/497 [==============================] - 94s 190ms/step - loss: 0.3459 - accuracy: 0.9441 - val_loss: 1.0743 - val_accuracy: 0.7215

# %%
#testing
acc = model.evaluate(test_generator)
# Out:
# 199/199 [==============================] - 10s 52ms/step - loss: 1.1150 - accuracy: 0.6985

# %%
print("MODEL AND HISTORY SAVED")
#save model
save_m(NORMAL_STUDENT_MODEL_PATH + 'NASNetMobile', model)
#save history
save_h(NORMAL_STUDENT_MODEL_PATH + 'NASNetMobile', history.history)
# Out:
# MODEL AND HISTORY SAVED

# %% [markdown]
# # **Training Visualization**

# %%
#VISUAL CUSTOMIZER
distiller_history = load_h(NORMAL_STUDENT_MODEL_PATH + 'NASNetMobile')

marker_t = '^'
marker_v = '+'
market_t_loss = 'v'
market_v_loss = 'x'
markersize = 5
fillstyle_t = 'none'
fillstyle_v = 'none'

color_t = 'blue'
color_v = 'orange'

labelsize = 10
fontsize = 7

color_t_loss = 'green'
color_v_loss = 'red'

border_pad = 0.5
legend_font_size = 9

ls_t = '-' 
ls_v = '--'
lw_t = '1.5'
lw_v = '1.5'

print("You may change the values if needed for the ease of your evaluation")
# Out:
# You may change the values if needed for the ease of your evaluation

# %% [markdown]
# **Accuracy Curve**

# %%
#PRINTS THE ACCURACY GROWTH
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300, edgecolor='black', facecolor='white', linewidth=0)
plt.tight_layout()

plt.gcf().subplots_adjust(bottom=0.15)

plt.rc('xtick',labelsize=labelsize, direction="in") 
plt.rc('ytick', labelsize=labelsize, direction="in") 
plt.tick_params(length=4, right=True, top=True)

plt.plot(np.arange(1, N+1), distiller_history["accuracy"], color=color_t,lw=lw_t, marker=marker_t, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Accuracy")
plt.plot(np.arange(1, N+1), distiller_history["val_accuracy"], color=color_v ,lw=lw_v, marker=marker_v, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v,  label="Validation Accuracy")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Accuracy", fontsize=fontsize, color='black')
plt.legend(loc="lower right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()

# %% [markdown]
# **Loss Curve**

# %%
#PRINTS THE DECREASE OF LOSS
N = EPOCHS
plt.style.use("default")
plt.figure(figsize=(5,4), dpi=300)
plt.plot(np.arange(1, N+1), distiller_history["loss"], color=color_t_loss,lw=lw_t, marker=market_t_loss, markersize=markersize, fillstyle=fillstyle_t, ls=ls_t, label="Train Loss")
plt.plot(np.arange(1, N+1), distiller_history["val_loss"], color=color_v_loss,lw=lw_v, marker=market_v_loss, markersize= markersize, fillstyle=fillstyle_v, ls=ls_v, label="Validation Loss")

plt.xlabel("Epochs", fontsize=fontsize, color='black')
plt.ylabel("Loss", fontsize=fontsize, color='black')
plt.legend(loc="upper right", fontsize=legend_font_size, edgecolor='black', borderpad=border_pad)
plt.tight_layout()
